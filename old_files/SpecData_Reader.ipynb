# %% [markdown]
# Spec data Reader
#
# John W. Freeland (APS/ANL)
#
# Updated 8/4/2019

# %%
#Load needed python routines

from matplotlib import pyplot as plt
import xrayutilities as xu
from scipy import misc
import imageio
import numpy as np
import peakutils
from matplotlib import rcParams
from IPython.display import display, clear_output

# %%
#Set Fonts

rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
rcParams.update({'font.size': 18})

# %%
#Provide path and spec filename. Uses X-ray utilities (xu) to open spec file.

specpath = "/home/beams/29IDUSER/spec/data/2019_2/Frano"
specfile = "August2019_YBCO_3"
s = xu.io.SPECFile(specfile,path=specpath)

# %%
#Set scan number and columns to read from spec file. Read into notebook.

scan = 559
Theta, i0, D4, Temp_K = xu.io.getspec_scan(s, scan,'Theta','Monitor','D4','TA')
# Out:
# XU.io.SPECScan.ReadData: scan_559: 61 60 60

# %%
#Plot data

plt.ylabel ('Intensity')
plt.xlabel('Theta')
plt.semilogy(Theta,D4,'b-o')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save subtracted data to file. Use np.save for .npy or np.savetxt for ascii

outfilename = 'HKLscan_S'+str(scan)
np.savetxt(outfilename, np.column_stack([H,K,L,Int_sum_mbkg,Int_sum,Int_bkg1,Int_bkg2]))
